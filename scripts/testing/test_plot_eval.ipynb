# %%
import sys
sys.path.append("/home/yuahe/projects/OntoAlign-py")
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
sns.set(style='darkgrid')
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = "Times New Roman"

# %%
eval_df = pd.read_csv("/home/yuahe/projects/OntoAlign-py/largebio_exp/small/fma2nci/bc-cls.eval.csv", index_col=0)

# %%
start = 12
combined = eval_df.iloc[start::3].reset_index().rename(columns={"index": "Threshold"})
src2tgt_inds = eval_df.iloc[start+1::3].reset_index().rename(columns={"index": "Threshold"})
tgt2src_inds = eval_df.iloc[start+2::3].reset_index().rename(columns={"index": "Threshold"})

# %%
combined["Threshold"] = combined["Threshold"].apply(lambda x: float(x.split(":")[1]))

# %%
# 
fig = sns.lineplot(data=combined.melt(id_vars="Threshold", value_vars=["Precision", "Recall", "F1"]), x="Threshold", y="value", hue="variable", marker='o')
fig.set(ylabel='Value', title='Plot of Precision, Recall and F1 against Threshold [Combined Mappings]')
fig
# Out:
# <AxesSubplot:title={'center':'Plot of Precision, Recall and F1 against Threshold [Combined Mappings]'}, xlabel='Threshold', ylabel='Value'>
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
