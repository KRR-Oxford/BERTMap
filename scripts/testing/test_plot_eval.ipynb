# %%
import sys
sys.path.append("../..")
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
from ontoalign.experiments import OntoAlignExperiment

# %%
eval_file = "../../largebio_exp/small/fma2nci/bc-cls.eval.csv"
start = 12

# %%
OntoAlignExperiment.plot_eval(eval_file, start_col=start).savefig("../../largebio_exp/small/fma2nci/bc-cls.png")
